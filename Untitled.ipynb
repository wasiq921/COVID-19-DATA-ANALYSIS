# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('owid-covid-data.csv')

# %%
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 91482      ZWE    Africa     Zimbabwe  2021-05-22      38679.0       15.0
# 91483      ZWE    Africa     Zimbabwe  2021-05-23      38682.0        3.0
# 91484      ZWE    Africa     Zimbabwe  2021-05-24      38696.0       14.0
# 91485      ZWE    Africa     Zimbabwe  2021-05-25      38706.0       10.0
# 91486      ZWE    Africa     Zimbabwe  2021-05-26      38819.0      113.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %%
df.tail()
# Out:
#       iso_code continent  location        date  total_cases  new_cases  \
# 91482      ZWE    Africa  Zimbabwe  2021-05-22      38679.0       15.0
# 91483      ZWE    Africa  Zimbabwe  2021-05-23      38682.0        3.0
# 91484      ZWE    Africa  Zimbabwe  2021-05-24      38696.0       14.0
# 91485      ZWE    Africa  Zimbabwe  2021-05-25      38706.0       10.0
# 91486      ZWE    Africa  Zimbabwe  2021-05-26      38819.0      113.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 91482              17.857        1586.0         0.0                0.571  ...
# 91483              17.429        1586.0         0.0                0.571  ...
# 91484              17.714        1586.0         0.0                0.571  ...
# 91485              15.857        1587.0         1.0                0.571  ...
# 91486              29.571        1589.0         2.0                0.857  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  8.873600e+04   88735.000000        87728.000000  7.887000e+04
# mean   9.231218e+05    6044.406333         6058.523461  2.495650e+04
# std    6.375823e+06   38139.178091        37796.003220  1.486867e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.065000e+03       2.000000            7.143000  4.800000e+01
# 50%    1.172200e+04      71.000000           87.857000  3.340000e+02
# 75%    1.243550e+05     785.000000          821.892750  3.250000e+03
# max    1.684128e+08  905992.000000       826374.286000  3.498443e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  79028.000000         87728.000000             88261.000000
# mean     141.946563           126.669720             11321.149292
# std      779.648869           718.569419             21387.351533
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
df.isnull().sum()
# Out:
# iso_code                                     0
# continent                                 4345
# location                                     0
# date                                         0
# total_cases                               2751
# new_cases                                 2752
# new_cases_smoothed                        3759
# total_deaths                             12617
# new_deaths                               12459
# new_deaths_smoothed                       3759
# total_cases_per_million                   3226
# new_cases_per_million                     3227
# new_cases_smoothed_per_million            4229
# total_deaths_per_million                 13079
# new_deaths_per_million                   12921
# new_deaths_smoothed_per_million           4229
# reproduction_rate                        17936
# icu_patients                             82176
# icu_patients_per_million                 82176
# hosp_patients                            79910
# ...

# %%
sns.relplot(x='total_cases', y='total_deaths', data=df)

# %%
sns.relplot(x='total_cases', y='total_deaths', data=df.iloc[0:100])

# %%
df['location'] == "Pakistan"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 91482    False
# 91483    False
# 91484    False
# 91485    False
# 91486    False
# Name: location, Length: 91487, dtype: bool

# %%
print('Total Cases and Total Death Ratio in Pakistan')
sns.relplot(x='total_cases', y='total_deaths', data=df.iloc[62816:63300])
# Out:
# Total Cases and Total Death Ratio in Pakistan

# %%
sns.relplot(x='total_vaccinations', y='total_cases', data=df.iloc[10000:30000])

# %%
sns.relplot(x='total_cases', y='total_deaths', data=df.iloc[0:10000])

# %%
sns.relplot(x='total_cases', y='total_deaths', data=df)
print('Around 10 Lakhs people have died in Covid among 10 crore cases')
# Out:
# Around 10 Lakhs people have died in Covid among 10 crore cases

# %%
sns.relplot(x='total_cases', y='hosp_patients', data=df)
print('according to this graph when covid cases were around 1.5 - 2.5 (1e7) then hospitalized patients were at high numbers more than 120000')
# Out:
# according to this graph when covid cases were around 1.5 - 2.5 (1e7) then hospitalized patients were at high numbers more than 120000

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %%
sns.relplot(x='total_deaths', y='total_cases', kind='line' , data=df)
